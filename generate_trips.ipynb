# %%
import pandas as pd

# %%
data = pd.read_csv("data_in/trip_profiles.csv")
data
# Out:
#                 Categorias             Perfis  Probabilidade
# 0        worker_1st_sector          H - W - H          0.650
# 1        worker_1st_sector      H - W - S - H          0.150
# 2        worker_1st_sector      H - W - L - H          0.150
# 3        worker_1st_sector  H - W - S - L - H          0.050
# 4        worker_2nd_sector          H - W - H          0.650
# 5        worker_2nd_sector      H - W - S - H          0.150
# 6        worker_2nd_sector      H - W - L - H          0.150
# 7        worker_2nd_sector  H - W - S - L - H          0.050
# 8        worker_3rd_sector          H - W - H          0.650
# 9        worker_3rd_sector      H - W - S - H          0.150
# 10       worker_3rd_sector      H - W - L - H          0.150
# 11       worker_3rd_sector  H - W - S - L - H          0.050
# 12  autonomous_or_employer          H - W - H          0.650
# 13  autonomous_or_employer      H - W - S - H          0.150
# ...
